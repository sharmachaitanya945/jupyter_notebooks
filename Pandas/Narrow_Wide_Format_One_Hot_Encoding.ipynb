# %% [markdown]
# # Narrow vs Wide Format & One-Hot Encoding
#
# This notebook covers:
# - Differences between Narrow (Long) and Wide Formats
# - Reshaping Data using Pandas
# - One-Hot Encoding using Pandas and Scikit-Learn
#
# **Complete the exercises by filling in the missing code!**

# %%
# Importing required libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Understanding Narrow vs Wide Format
# ### Exercise: Convert a Wide Format dataset into a Narrow Format

# %%
# Creating a sample wide format dataset
df_wide = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Math': [85, 90, 88],
    'Science': [78, 92, 80],
    'English': [82, 85, 87]
})
df_wide

# %%
# TODO: Convert wide format to narrow format using melt()
df_narrow = df_wide.melt(id_vars=['____'], var_name='Subject', value_name='Score')
df_narrow

# %% [markdown]
# ## 2. Reshaping Data
# ### Exercise: Convert Narrow Format back to Wide Format

# %%
# TODO: Convert narrow format back to wide format using pivot()
df_wide_again = df_narrow.pivot(index='____', columns='____', values='____')
df_wide_again

# %% [markdown]
# ## 3. One-Hot Encoding
# ### Exercise: Perform One-Hot Encoding on a Categorical Column

# %%
# Creating a sample dataset with a categorical column
df_categorical = pd.DataFrame({
    'Person': ['Alice', 'Bob', 'Charlie', 'David'],
    'Favorite_Color': ['Red', 'Blue', 'Green', 'Blue']
})
df_categorical

# %%
# TODO: Perform One-Hot Encoding using Pandas
df_encoded = pd.get_dummies(df_categorical, columns=['____'])
df_encoded

# %% [markdown]
# ## 4. One-Hot Encoding using Scikit-Learn
# ### Exercise: Encode categorical data using OneHotEncoder

# %%
# Importing OneHotEncoder from sklearn
from sklearn.preprocessing import OneHotEncoder

# Initializing OneHotEncoder
encoder = OneHotEncoder(sparse=False)

# TODO: Fit and transform the categorical column
encoded_array = encoder.fit_transform(df_categorical[['____']])
encoded_array

# %% [markdown]
# # 🎯 Conclusion
# You have successfully practiced reshaping data and applying One-Hot Encoding!
