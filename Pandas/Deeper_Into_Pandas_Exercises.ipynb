# %% [markdown]
# # Deeper into Pandas
#
# This notebook covers advanced Pandas operations, including:
# - Transforming Data
# - Manipulating Data
# - Combining Data
# - Working with the Iris Dataset
#
# **Complete the exercises by filling in the missing code!**

# %%
# Importing required libraries
import pandas as pd
import seaborn as sns

# Load the Iris dataset
df = sns.load_dataset('iris')
df.head()

# %% [markdown]
# ## 1. Transforming Data
# ### Exercise: Convert all column names to uppercase

# %%
# TODO: Convert all column names to uppercase
df.columns = [____ for col in df.columns]
df.head()

# %% [markdown]
# ## 2. Manipulating Data
# ### Exercise: Filter the dataset to show only rows where petal_length > 4.5

# %%
# TODO: Filter rows where petal_length > 4.5
df_filtered = df[df['petal_length'] > ____]
df_filtered.head()

# %% [markdown]
# ## 3. Combining Data
# ### Exercise: Split the dataset into two parts and then concatenate them back

# %%
# TODO: Split and concatenate the dataset
df_part1 = df.iloc[:75]
df_part2 = df.iloc[75:]
df_combined = pd.concat([____, ____], axis=0)
df_combined.head()

# %% [markdown]
# ## 4. Understanding Pandas Patterns
# ### Exercise: Use the apply() function to create a new column

# %%
# TODO: Create a new column that categorizes petal_length
def categorize_petal_length(length):
    if length < 2.5:
        return 'Short'
    elif length < 5.0:
        return 'Medium'
    else:
        return 'Long'

df['Petal_Category'] = df['petal_length'].____(categorize_petal_length)
df.head()
